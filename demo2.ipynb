# %%
# %matplotlib inline
from qiskit import QuantumCircuit, transpile
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt
from qiskit.quantum_info import Statevector
from qiskit.visualization import plot_bloch_multivector

#Circuit
qc = QuantumCircuit(3)
qc.h(0)
qc.h(1)
qc.ccx(0, 1, 2)

#Block Vector visualization
state = Statevector.from_instruction(qc)
plot_bloch_multivector(state)

qc.measure_all()

#Simulate
sim = AerSimulator()
#Corrected line: Use the global transpile function
compiled = transpile(qc, sim)
result = sim.run(compiled, shots = 1024).result()
counts = result.get_counts()

#Output
qc.draw(output = 'mpl')
print("Measurement cicruit: ", counts)
o=plot_histogram(counts)
plt.show()
# Out:
# Measurement cicruit:  {'001': 261, '111': 240, '010': 263, '000': 260}

# %%
# !pip install qiskit-aer
# Out:
# Collecting qiskit-aer
#   Downloading qiskit_aer-0.17.2-cp314-cp314-win_amd64.whl.metadata (8.4 kB)
# Requirement already satisfied: qiskit>=1.1.0 in c:\users\aayush\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from qiskit-aer) (2.4.1)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\aayush\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from qiskit-aer) (2.4.3)
# Requirement already satisfied: scipy>=1.0 in c:\users\aayush\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from qiskit-aer) (1.17.1)
# Requirement already satisfied: psutil>=5 in c:\users\aayush\appdata\roaming\python\python314\site-packages (from qiskit-aer) (7.2.2)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\aayush\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\aayush\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from python-dateutil>=2.8.0->qiskit-aer) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in c:\users\aayush\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from qiskit>=1.1.0->qiskit-aer) (0.17.1)
# Requirement already satisfied: dill>=0.3 in c:\users\aayush\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from qiskit>=1.1.0->qiskit-aer) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in c:\users\aayush\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from qiskit>=1.1.0->qiskit-aer) (5.8.0)
# Requirement already satisfied: typing-extensions in c:\users\aayush\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from qiskit>=1.1.0->qiskit-aer) (4.15.0)
# Downloading qiskit_aer-0.17.2-cp314-cp314-win_amd64.whl (9.7 MB)
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---- ----------------------------------- 1.0/9.7 MB 10.9 MB/s eta 0:00:01
#    --------------- ------------------------ 3.7/9.7 MB 11.1 MB/s eta 0:00:01
#    ------------------------ --------------- 6.0/9.7 MB 11.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 8.7/9.7 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 11.3 MB/s  0:00:00
# Installing collected packages: qiskit-aer
# Successfully installed qiskit-aer-0.17.2
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\aayush\appdata\local\python\pythoncore-3.14-64\lib\site-packages (25.3)
# Collecting pip
#   Downloading pip-26.1.2-py3-none-any.whl.metadata (4.6 kB)
# Downloading pip-26.1.2-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ----------------- ---------------------- 0.8/1.8 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.8/1.8 MB 10.2 MB/s  0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.3
#     Uninstalling pip-25.3:
#       Successfully uninstalled pip-25.3
# Successfully installed pip-26.1.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts pip.exe, pip3.14.exe and pip3.exe are installed in 'c:\Users\Aayush\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
