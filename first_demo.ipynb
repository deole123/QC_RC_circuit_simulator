# %%
import qiskit
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import qiskit
#
# ModuleNotFoundError: No module named 'qiskit'

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Aayush\AppData\Local\Python\pythoncore-3.14-64\python.exe

# %%
# !pip list | findstr qiskit

# %%
# !pip --version
# Out:
# pip 25.3 from C:\Users\Aayush\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\pip (python 3.14)

# %%
# !pip install qiskit
# Out:
# Collecting qiskit
#   Using cached qiskit-2.4.1-cp310-abi3-win_amd64.whl.metadata (13 kB)
# Collecting rustworkx>=0.15.0 (from qiskit)
#   Using cached rustworkx-0.17.1-cp39-abi3-win_amd64.whl.metadata (10 kB)
# Requirement already satisfied: numpy<3,>=1.21 in c:\users\aayush\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from qiskit) (2.4.3)
# Collecting scipy>=1.5 (from qiskit)
#   Downloading scipy-1.17.1-cp314-cp314-win_amd64.whl.metadata (60 kB)
# Collecting dill>=0.3 (from qiskit)
#   Using cached dill-0.4.1-py3-none-any.whl.metadata (10 kB)
# Collecting stevedore>=3.0.0 (from qiskit)
#   Using cached stevedore-5.8.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting typing-extensions (from qiskit)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Using cached qiskit-2.4.1-cp310-abi3-win_amd64.whl (9.1 MB)
# Using cached dill-0.4.1-py3-none-any.whl (120 kB)
# Using cached rustworkx-0.17.1-cp39-abi3-win_amd64.whl (2.1 MB)
# Downloading scipy-1.17.1-cp314-cp314-win_amd64.whl (37.3 MB)
#    ---------------------------------------- 0.0/37.3 MB ? eta -:--:--
#    - -------------------------------------- 1.8/37.3 MB 10.7 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.5/37.3 MB 11.4 MB/s eta 0:00:03
#    ------- -------------------------------- 6.8/37.3 MB 11.6 MB/s eta 0:00:03
#    ---------- ----------------------------- 9.4/37.3 MB 11.6 MB/s eta 0:00:03
#    ------------ --------------------------- 11.8/37.3 MB 11.6 MB/s eta 0:00:03
#    --------------- ------------------------ 14.4/37.3 MB 11.6 MB/s eta 0:00:02
#    ------------------ --------------------- 17.0/37.3 MB 11.7 MB/s eta 0:00:02
#    --------------------- ------------------ 19.7/37.3 MB 11.7 MB/s eta 0:00:02
#    ----------------------- ---------------- 22.3/37.3 MB 11.7 MB/s eta 0:00:02
#    -------------------------- ------------- 24.6/37.3 MB 11.7 MB/s eta 0:00:02
#    ----------------------------- ---------- 27.5/37.3 MB 11.7 MB/s eta 0:00:01
#    -------------------------------- ------- 29.9/37.3 MB 11.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 32.0/37.3 MB 11.6 MB/s eta 0:00:01
#    ------------------------------------ --- 34.3/37.3 MB 11.5 MB/s eta 0:00:01
#    ---------------------------------------  36.4/37.3 MB 11.4 MB/s eta 0:00:01
#    ---------------------------------------- 37.3/37.3 MB 11.2 MB/s  0:00:03
# Using cached stevedore-5.8.0-py3-none-any.whl (54 kB)
# Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Installing collected packages: typing-extensions, stevedore, scipy, rustworkx, dill, qiskit
#
#    ------ --------------------------------- 1/6 [stevedore]
#    ------ --------------------------------- 1/6 [stevedore]
#    ------ --------------------------------- 1/6 [stevedore]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    ------------- -------------------------- 2/6 [scipy]
#    -------------------- ------------------- 3/6 [rustworkx]
#    -------------------------- ------------- 4/6 [dill]
#    -------------------------- ------------- 4/6 [dill]
#    -------------------------- ------------- 4/6 [dill]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    --------------------------------- ------ 5/6 [qiskit]
#    ---------------------------------------- 6/6 [qiskit]
#
# Successfully installed dill-0.4.1 qiskit-2.4.1 rustworkx-0.17.1 scipy-1.17.1 stevedore-5.8.0 typing-extensions-4.15.0
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import qiskit

# %%
from qiskit import QuantumCircuit
qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0, 1)
qc.draw(output = 'mpl')
# Out:
# ---------------------------------------------------------------------------
# MissingOptionalLibraryError               Traceback (most recent call last)
# Cell In[9], line 5
#       1 from qiskit import QuantumCircuit
#       2 qc = QuantumCircuit(2)
#       3 qc.h(0)
#       4 qc.cx(0, 1)
# ----> 5 qc.draw(output = 'mpl')
#
# File c:\Users\Aayush\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\qiskit\circuit\quantumcircuit.py:4040, in QuantumCircuit.draw(self, output, scale, filename, style, interactive, plot_barriers, reverse_bits, justify, vertical_compression, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len, measure_arrows, barrier_label_len)
#    3895 r"""Draw the quantum circuit. Use the output parameter to choose the drawing format:
#    3896
#    3897 ``text``
#    (...)   4035        qc.draw(output='mpl', style={'backgroundcolor': '#EEEEEE'})
#    4036 """
#    4038 from qiskit.visualization import circuit_drawer
# -> 4040 return circuit_drawer(
#    4041     self,
#    4042     scale=scale,
#    4043     filename=filename,
#    4044     style=style,
#    4045     output=output,
#    4046     interactive=interactive,
#    4047     plot_barriers=plot_barriers,
#    4048     reverse_bits=reverse_bits,
#    4049     justify=justify,
#    4050     vertical_compression=vertical_compression,
#    4051     idle_wires=idle_wires,
#    4052     with_layout=with_layout,
#    4053     fold=fold,
#    4054     ax=ax,
#    4055     initial_state=initial_state,
#    4056     cregbundle=cregbundle,
#    4057     wire_order=wire_order,
#    4058     expr_len=expr_len,
#    4059     barrier_label_len=barrier_label_len,
#    4060     measure_arrows=measure_arrows,
#    4061 )
#
# File c:\Users\Aayush\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\qiskit\visualization\circuit\circuit_visualization.py:368, in circuit_drawer(circuit, scale, filename, style, output, interactive, plot_barriers, reverse_bits, justify, vertical_compression, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len, measure_arrows, barrier_label_len)
#     352     return _generate_latex_source(
#     353         circuit,
#     354         filename=filename,
#    (...)    365         barrier_label_len=barrier_label_len,
#     366     )
#     367 elif output == "mpl":
# --> 368     image = _matplotlib_circuit_drawer(
#     369         circuit,
#     370         scale=scale,
#     371         filename=filename,
#     372         style=style,
#     373         plot_barriers=plot_barriers,
#     374         reverse_bits=reverse_bits,
#     375         justify=justify,
#     376         idle_wires=idle_wires,
#     377         with_layout=with_layout,
#     378         fold=fold,
#     379         ax=ax,
#     380         initial_state=initial_state,
#     381         cregbundle=cregbundle,
#     382         wire_order=complete_wire_order,
#     383         expr_len=expr_len,
#     384         measure_arrows=measure_arrows,
#     385         barrier_label_len=barrier_label_len,
#     386     )
#     387 else:
#     388     raise VisualizationError(
#     389         f"Invalid output type {output} selected. The only valid choices "
#     390         "are text, latex, latex_source, and mpl"
#     391     )
#
# File c:\Users\Aayush\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\qiskit\visualization\circuit\circuit_visualization.py:776, in _matplotlib_circuit_drawer(circuit, scale, filename, style, plot_barriers, reverse_bits, justify, idle_wires, with_layout, fold, ax, initial_state, cregbundle, wire_order, expr_len, measure_arrows, barrier_label_len)
#     773 if fold is None:
#     774     fold = 25
# --> 776 qcd = _matplotlib.MatplotlibDrawer(
#     777     qubits,
#     778     clbits,
#     779     nodes,
#     780     circuit,
#     781     scale=scale,
#     782     style=style,
#     783     reverse_bits=reverse_bits,
#     784     plot_barriers=plot_barriers,
#     785     fold=fold,
#     786     ax=ax,
#     787     initial_state=initial_state,
#     788     cregbundle=cregbundle,
#     789     with_layout=with_layout,
#     790     expr_len=expr_len,
#     791     barrier_label_len=barrier_label_len,
#     792     measure_arrows=measure_arrows,
#     793 )
#     794 return qcd.draw(filename)
#
# File c:\Users\Aayush\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\qiskit\utils\classtools.py:111, in _WrappedMethod.__get__.<locals>.out(*args, **kwargs)
#     108 @functools.wraps(method)
#     109 def out(*args, **kwargs):
#     110     for callback in self._before:
# --> 111         callback.__get__(obj, objtype)(*args, **kwargs)
#     112     retval = method(*args, **kwargs)
#     113     for callback in self._after:
#
# File c:\Users\Aayush\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\qiskit\utils\lazy_tester.py:42, in _RequireNow.__call__(self, *_args, **_kwargs)
#      41 def __call__(self, *_args, **_kwargs):
# ---> 42     self._tester.require_now(self._feature)
#
# File c:\Users\Aayush\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\qiskit\utils\lazy_tester.py:222, in LazyDependencyManager.require_now(self, feature)
#     220 if self:
#     221     return
# --> 222 raise MissingOptionalLibraryError(
#     223     libname=self._name, name=feature, pip_install=self._install, msg=self._msg
#     224 )
#
# MissingOptionalLibraryError: "The 'pylatexenc' library is required to use 'MatplotlibDrawer'. You can install it with 'pip install pylatexenc'."

# %%
# !pip install matplotlib pylatexenc
# Out:
# Requirement already satisfied: matplotlib in c:\users\aayush\appdata\local\python\pythoncore-3.14-64\lib\site-packages (3.10.8)
# Collecting pylatexenc
#   Using cached pylatexenc-2.10.tar.gz (162 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aayush\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\aayush\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aayush\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aayush\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\aayush\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\aayush\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\aayush\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\aayush\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aayush\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\aayush\appdata\local\python\pythoncore-3.14-64\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Building wheels for collected packages: pylatexenc
#   Building wheel for pylatexenc (pyproject.toml): started
#   Building wheel for pylatexenc (pyproject.toml): finished with status 'done'
#   Created wheel for pylatexenc: filename=pylatexenc-2.10-py3-none-any.whl size=138971 sha256=0214be0042bd208dab39fec1a946c6356668c57f11e40596456ca8f065463657
#   Stored in directory: c:\users\aayush\appdata\local\pip\cache\wheels\6e\51\1c\e4691ba960b6fe12c01239f26bc63c58d5c4e754b58ace903d
# Successfully built pylatexenc
# Installing collected packages: pylatexenc
# Successfully installed pylatexenc-2.10
#   WARNING: The scripts latex2text.exe, latexencode.exe and latexwalker.exe are installed in 'C:\Users\Aayush\AppData\Local\Python\pythoncore-3.14-64\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.3 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
python.exe -m pip install --upgrade pip
# Out:
#   Cell In[12], line 1
#     python.exe -m pip install --upgrade pip
#                   ^
# SyntaxError: invalid syntax

# %%
from qiskit import QuantumCircuit
qc = QuantumCircuit(2)
qc.h(0)
qc.cx(0, 1)
qc.draw(output = 'mpl')
